# %%
import numpy as np
import data
from copy import deepcopy

# %% [markdown]
# # k = 3

# %%
k=3
n=200
dimension=2
mu_list = np.array([ [2,6], [8,10], [8,2] ])
sigma_list = np.array([ [[1,0],[0,3]], [[3,0],[0,2]], [[3,0],[0,3]] ])
X = data.generate_data(k, n, dimension, mu_list, sigma_list)
real_lable = deepcopy(X[:, -1])
print(mu_list)
data.show(X, mu_list, title='Real Data Distribution')
# Out:
# [[ 2  6]
#  [ 8 10]
#  [ 8  2]]

# %% [markdown]
# ### k-means

# %%
X, center, iterations = data.kmeans(X, k, epsilon=1)
print(center)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, center, title='epsilon=1, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
X, center, iterations = data.kmeans(X, k, epsilon=1e-5)
print(center)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, center, title='epsilon=1e-5, iterations=' + str(iterations) + 'accuracy=' + str(accuracy))
X, center, iterations = data.kmeans(X, k, epsilon=1e-10)
print(center)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, center, title='epsilon=1e-10, iterations=' + str(iterations) + 'accuracy=' + str(accuracy))
# Out:
# [[ 8.01793576  1.79108972]
#  [ 8.03150573 10.1021806 ]
#  [ 2.24065269  5.92428314]]
# [[ 8.0836514  10.09409582]
#  [ 2.13241573  6.07466331]
#  [ 7.90305055  1.85080409]]
# [[ 7.90305055  1.85080409]
#  [ 2.13241573  6.07466331]
#  [ 8.0836514  10.09409582]]

# %% [markdown]
# ### GMM

# %%
X, iterations, log_l_list = data.gmm(X, k, 1)
print(log_l_list)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, title='epsilon=1, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
X, iterations, log_l_list = data.gmm(X, k, epsilon=1e-5)
print(log_l_list)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, title='epsilon=1e-5, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
X, iterations, log_l_list = data.gmm(X, k, epsilon=1e-7)
print(log_l_list)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, title='epsilon=1e-7, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
# Out:
#   Iterations  log likelihood
# 0          0   -18226.956449
# 1         10    -3689.970247
# 2         20    -3692.195322
# 3         30    -3692.195794
# 4         40    -3692.195794
#   Iterations  log likelihood
# 0          0   -32211.187468
# 1         10    -3687.083203
# 2         20    -3692.195100
# 3         30    -3692.195794
#   Iterations  log likelihood
# 0          0   -18226.956449
# 1         10    -3689.970247
# 2         20    -3692.195322
# 3         30    -3692.195794
# 4         40    -3692.195794

# %% [markdown]
# # k = 5

# %%
k=5
n=200
dimension=2
mu_list = np.array([ [2,2], [2,8], [5,5], [8,2], [8,8] ])
sigma_list = np.array([ [[1,0],[0,2]], [[3,0],[0,1]], [[2,0],[0,2]], [[2,0],[0,3]], [[1,0],[0,1]] ])
X = data.generate_data(k, n, dimension, mu_list, sigma_list)
real_lable = deepcopy(X[:, -1])
print(mu_list)
data.show(X, mu_list, title='Real Data Distribution')
# Out:
# [[2 2]
#  [2 8]
#  [5 5]
#  [8 2]
#  [8 8]]

# %% [markdown]
# ### k-means

# %%
X, center, iterations = data.kmeans(X, k, epsilon=1)
print(center)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, center, title='epsilon=1, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
X, center, iterations = data.kmeans(X, k, epsilon=1e-5)
print(center)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, center, title='epsilon=1e-5, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
X, center, iterations = data.kmeans(X, k, epsilon=1e-10)
print(center)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, center, title='epsilon=1e-10, iterations=' + str(iterations) + 'accuracy=' + str(accuracy))
# Out:
# [[1.81126365 1.70455608]
#  [7.98534324 1.60414057]
#  [4.68148749 4.42232503]
#  [7.92856289 7.40125028]
#  [2.31526297 7.84828289]]
# [[8.06352571 1.74963954]
#  [7.95994276 7.75805996]
#  [1.86714372 7.97501538]
#  [5.08440337 5.18070716]
#  [2.03251864 1.8425656 ]]
# [[1.86714372 7.97501538]
#  [8.06352571 1.74963954]
#  [7.95994276 7.75805996]
#  [5.08440337 5.18070716]
#  [2.03251864 1.8425656 ]]

# %% [markdown]
# ### GMM

# %%
X, iterations, log_l_list = data.gmm(X, k, 1)
print(log_l_list)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, title='epsilon=1, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
X, iterations, log_l_list = data.gmm(X, k, epsilon=1e-5)
print(log_l_list)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, title='epsilon=1e-5, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
X, iterations, log_l_list = data.gmm(X, k, epsilon=1e-10)
print(log_l_list)
accuracy = data.accuracy(real_lable, X[:, -1], k)
data.show(X, title='epsilon=1e-10, iterations=' + str(iterations) + ', accuracy=' + str(accuracy))
# Out:
#   Iterations  log likelihood
# 0          0    -7259.752107
# 1         10    -4765.314022
#    Iterations  log likelihood
# 0           0   -21654.908621
# 1          10    -4726.982015
# 2          20    -4592.452950
# 3          30    -4476.627849
# 4          40    -4279.406671
# 5          50    -4180.283569
# 6          60    -4152.221810
# 7          70    -4142.624783
# 8          80    -4138.771316
# 9          90    -4137.080816
# 10        100    -4136.300408
# 11        110    -4135.927606
# 12        120    -4135.744660
# 13        130    -4135.652762
# 14        140    -4135.605617
# 15        150    -4135.580966
# 16        160    -4135.567856
# 17        170    -4135.560781
# 18        180    -4135.556914
# 19        190    -4135.554778
# 20        200    -4135.553588
# 21        210    -4135.552921
# 22        220    -4135.552544
# 23        230    -4135.552331
#    Iterations  log likelihood
# 0           0   -21654.908621
# 1          10    -4726.982015
# ...

# %% [markdown]
# # UCI Iris数据集

# %%
X = data.uci_iris()
real_lable = deepcopy(X[:, -1])
k = 3
# k-means
print('\nK-means')
X, center, iterations = data.kmeans(X, k, epsilon=1)
accuracy = data.accuracy(real_lable, X[:, -1], k)
print(center)
print('epsilon=1, iterations=' + str(iterations) + ', accuracy=' + str(accuracy) + '\n')

X, center, iterations = data.kmeans(X, k, epsilon=1e-5)
accuracy = data.accuracy(real_lable, X[:, -1], k)
print(center)
print('epsilon=1e-5, iterations=' + str(iterations) + ', accuracy=' + str(accuracy) + '\n')

X, center, iterations = data.kmeans(X, k, epsilon=1e-10)
accuracy = data.accuracy(real_lable, X[:, -1], k)
print(center)
print('epsilon=1e-10, iterations=' + str(iterations) + ', accuracy=' + str(accuracy) + '\n')

# GMM
print('\nGMM')
X, iterations, log_l_list = data.gmm(X, k, epsilon=1)
accuracy = data.accuracy(real_lable, X[:, -1], k)
print(log_l_list)
print('epsilon=1, iterations=' + str(iterations) + ', accuracy=' + str(accuracy) + '\n')

X, iterations, log_l_list = data.gmm(X, k, epsilon=1e-5)
accuracy = data.accuracy(real_lable, X[:, -1], k)
print(log_l_list)
print('epsilon=1e-5, iterations=' + str(iterations) + ', accuracy=' + str(accuracy) + '\n')

X, iterations, log_l_list = data.gmm(X, k, epsilon=1e-10)
accuracy = data.accuracy(real_lable, X[:, -1], k)
print(log_l_list)
print('epsilon=1e-10, iterations=' + str(iterations) + ', accuracy=' + str(accuracy) + '\n')
# Out:
# K-means
# [[5.00784314 3.4        1.49411765 0.26078431]
#  [6.84545455 3.02954545 5.53863636 1.95227273]
#  [5.81636364 2.75272727 4.43454545 1.46545455]]
# epsilon=1, iterations=2, accuracy=0.8733333333333333
#
# [[5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85384615 3.07692308 5.71538462 2.05384615]]
# epsilon=1e-5, iterations=5, accuracy=0.8866666666666667
#
# [[5.88360656 2.74098361 4.38852459 1.43442623]
#  [5.006      3.418      1.464      0.244     ]
#  [6.85384615 3.07692308 5.71538462 2.05384615]]
# epsilon=1e-10, iterations=10, accuracy=0.8866666666666667
#
#
# GMM
#   Iterations  log likelihood
# 0          0     -340.267489
# 1         10      180.479148
# epsilon=1, iterations=11, accuracy=0.76
#
#   Iterations  log likelihood
# 0          0     -340.267489
# 1         10      180.479148
# 2         20      167.034569
# 3         30      167.032893
# 4         40      167.032705
# 5         50      167.032697
# ...
